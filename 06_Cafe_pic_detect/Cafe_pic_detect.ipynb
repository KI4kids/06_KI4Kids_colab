# %%
# yoloV5 Objectdetection mit Bilder
# Lade und installiere yolov5 und pytorch

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # check

# %%
#Lade ein neues Bild (Verzeichnis yolov5)
from google.colab import drive
uploaded = files.upload()

# %%
#Lade das Bild
image_path = '/content/yolov5/cafe.jpg'
Image(filename=image_path, width=600)

# %%
#Objekterkennung "cafe.jpg"
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/yolov5/cafe.jpg

# %%
#Lade das Bild
image_path = '/content/yolov5/runs/detect/exp/cafe.jpg'
Image(filename=image_path, width=600)

# %%
#Lade ein neues Bild in das Verzeichnis yolov5
from google.colab import drive
uploaded = files.upload()

# %%
#Objekterkennung "imcafe.jpg"
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/yolov5/imcafe.jpg

# %%
#Lade das Bild imcafe.jpg
image_path = '/content/yolov5/runs/detect/exp2/imcafe.jpg'
Image(filename=image_path, width=600)
