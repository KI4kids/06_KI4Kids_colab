# %%
# yoloV5 Objectdetection mit Bilder
# Lade und installiere yolov5 und pytorch

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # check
# Out:
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.1/107.7 GB disk)

# %%
#Lade ein neues Bild (Verzeichnis yolov5)
from google.colab import drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8994bc3a-893b-44b4-9fe6-11f308dac8d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8994bc3a-893b-44b4-9fe6-11f308dac8d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Lade das Bild
image_path = '/content/yolov5/Jogger2.png'
from IPython.display import Image
Image(filename=image_path, width=600)

# %%
#Lade best.pt
from google.colab import drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-08acbd37-6c18-4675-9a44-65b0ba1a1f2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08acbd37-6c18-4675-9a44-65b0ba1a1f2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Lade yolo11n-pose.pt
from google.colab import drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d91edf2-97d2-45ec-b1d1-974542f6fe0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d91edf2-97d2-45ec-b1d1-974542f6fe0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# pose.py
# Zeigt Workout Bild

from ultralytics import YOLO

# Lade das Modell
model = YOLO("yolo11n-pose.pt")

# Lade das Bild
results = model(["Jogger2.png"])

# Ergebnisse verarbeiten
for result in results:
    boxes = result.boxes  # Boxenobjekt für Bounding-Box-Ausgaben
    masks = result.masks  # Maskenobjekt für die Ausgaben von Segmentierungsmasken
    keypoints = result.keypoints  # Schlüsselpunktobjekt für Pose-Ausgaben
    probs = result.probs  # Wahrscheinlichkeitsobjekt für Klassifikationsausgaben
    obb = result.obb  # Orientierte Boxenobjekte für OBB-Ausgaben
    result.show()  # Auf dem Bildschirm anzeigen
    result.save(filename="Pose.jpg")  # Auf die Festplatte speichern
# Out:
# 0: 640x416 2 persons, 366.4ms
# Speed: 38.3ms preprocess, 366.4ms inference, 37.2ms postprocess per image at shape (1, 3, 640, 416)
# <PIL.Image.Image image mode=RGB size=800x1230>
