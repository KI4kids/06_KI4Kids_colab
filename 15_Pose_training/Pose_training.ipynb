# %%
# yoloV5 Objectdetection mit Bilder
# Lade und installiere yolov5 und pytorch

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # check
# Out:
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.2/107.7 GB disk)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-pose.yaml")  # build a new model from YAML
model = YOLO("yolo11n-pose.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n-pose.yaml").load("yolo11n-pose.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="coco8-pose.yaml", epochs=10, imgsz=640)  # !!!!!!!!!!!!!!!!!!epochs=10!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# Transferred 490/541 items from pretrained weights
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
#Liste das Trainingsergebnis auf
# !dir '/content/yolov5/runs/pose/train/weights'
# Out:
# best.pt  last.pt
