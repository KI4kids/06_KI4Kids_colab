# %%
# %cd ..
# Out:
# /

# %%
#Lade ein neues Bild (Verzeichnis yolov5)
from google.colab import drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5775b68e-419c-45fe-a196-1899eb6a6a70" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5775b68e-419c-45fe-a196-1899eb6a6a70">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Lade das Bild
from IPython.display import Image
image_path = '/Klasse.jpg'
Image(filename=image_path, width=600)

# %%
pip install ultralytics

# %%
# Object detection on an image
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolov8n.pt") # You can change to a different YOLO model if needed

# Define the path to your image
image_path = '/Klasse.jpg'

# Perform object detection on the image
results = model(image_path)

# Show the results
results[0].show()

# Save the results (optional)
# results[0].save(filename="klasse_detected.jpg")
# Out:
# ...
#
# image 1/1 /Klasse.jpg: 448x640 8 persons, 419.3ms
# Speed: 14.7ms preprocess, 419.3ms inference, 30.8ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=1600x1067>

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.9 MB/s eta 0:00:00
# ...
