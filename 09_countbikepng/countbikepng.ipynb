# %%
from google.colab import files
from IPython.display import Image

# %%
from google.colab import drive
uploaded = files.upload()

# %%
# !ls /content

# %%
#Lade das Bild
image_path = '/content/bike.png'
display.Image(filename=image_path, width=600)

# %%
# yoloV5 Objectdetection mit Bilder
# Lade und installiere yolov5 und pytorch

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # chec

# %%
import os
# Get the current working directory
cwd = os.getcwd()

#Original Image
image_path = '/content/bike.png'
display.Image(filename=image_path, width=600)

# %%
#Objekterkennung "Bike"
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/bike.png

# %%
#Lade das Bild
image_path = '/content/yolov5/runs/detect/exp2/bike.png'
display.Image(filename=image_path, width=600)
